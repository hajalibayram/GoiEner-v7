# %%
import polars as pl

# %% [markdown]
# ## Metadata

# %%
metadata = pl.read_csv('data/metadata_post_covid_households_year.csv', try_parse_dates=True, schema_overrides= {'cnae':pl.String, 'postal_code':pl.String, 'start_date':pl.Date, 'end_date':pl.Date, 'p1_kw':pl.String, 'count_at_least_this_many_days':pl.Int16})

# metadata = metadata.with_columns(
#     pl.when(pl.col("postal_code").str.len_chars() == 4)
#       .then(pl.lit("0") + pl.col("postal_code"))
#       .otherwise(pl.col("postal_code"))
#       .alias("postal_code")
# ).drop("ref", "_ref")

metadata
# Out:
# shape: (3_385, 8)
# ┌────────────────┬────────────┬────────────┬──────┬─────────────┬───────┬─────────┬────────────────┐
# │ id             ┆ start_date ┆ end_date   ┆ cnae ┆ postal_code ┆ p1_kw ┆ tarriff ┆ days_from_ref_ │
# │ ---            ┆ ---        ┆ ---        ┆ ---  ┆ ---         ┆ ---   ┆ ---     ┆ to_end         │
# │ str            ┆ date       ┆ date       ┆ str  ┆ str         ┆ str   ┆ str     ┆ ---            │
# │                ┆            ┆            ┆      ┆             ┆       ┆         ┆ i64            │
# ╞════════════════╪════════════╪════════════╪══════╪═════════════╪═══════╪═════════╪════════════════╡
# │ 002b95326c8255 ┆ 2021-11-17 ┆ 2022-11-18 ┆ 9820 ┆ 20490       ┆ 3.5   ┆ 2.0TD   ┆ 366            │
# │ f7d54f4da5a9fb ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ 27…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ 002da62dc54b7a ┆ 2021-06-01 ┆ 2022-08-19 ┆ 9820 ┆ 31015       ┆ 3.45  ┆ 2.0TD   ┆ 444            │
# │ 789473182feddf ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ ad…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ 00372feea8da6d ┆ 2021-06-01 ┆ 2023-05-15 ┆ 9820 ┆ 12469       ┆ 3.45  ┆ 2.0TD   ┆ 713            │
# │ d7ee0a404bd7f3 ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ bd…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ 0050b980111bad ┆ 2021-06-01 ┆ 2022-10-25 ┆ 9821 ┆ 31243       ┆ 3.3   ┆ 2.0TD   ┆ 511            │
# │ 9422575db977d1 ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ 81…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ 0056ba30d63bfa ┆ 2022-03-05 ┆ 2023-05-17 ┆ 9820 ┆ 20800       ┆ 2.3   ┆ 2.0TD   ┆ 438            │
# │ aaabfaf337b312 ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ ab…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ …              ┆ …          ┆ …          ┆ …    ┆ …           ┆ …     ┆ …       ┆ …              │
# │ ffc4e2630581bc ┆ 2022-01-27 ┆ 2023-05-17 ┆ 9820 ┆ 48650       ┆ 4.6   ┆ 2.0TD   ┆ 475            │
# │ e53d9075c7455d ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ fa…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ ffd19f52a6fd57 ┆ 2021-06-01 ┆ 2023-10-24 ┆ 9820 ┆ 1015        ┆ 3.45  ┆ 2.0TD   ┆ 875            │
# │ 060368ae718393 ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ de…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ ffe091e941a9d6 ┆ 2021-06-01 ┆ 2023-05-31 ┆ 9820 ┆ 31810       ┆ 9.0   ┆ 3.0TD   ┆ 729            │
# │ 41abb55b40df22 ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ 2c…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ ffe48aa8a0036f ┆ 2021-06-01 ┆ 2023-05-15 ┆ 9820 ┆ 1191        ┆ 1.15  ┆ 2.0TD   ┆ 713            │
# │ e7add026a1f836 ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ bf…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ ffeddf4919e748 ┆ 2021-06-01 ┆ 2022-12-19 ┆ 9820 ┆ 42153       ┆ 6.0   ┆ 2.0TD   ┆ 566            │
# │ beb50af7c6b73d ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# │ ef…            ┆            ┆            ┆      ┆             ┆       ┆         ┆                │
# └────────────────┴────────────┴────────────┴──────┴─────────────┴───────┴─────────┴────────────────┘

# %% [markdown]
# ## CSVs

# %%
households_df = pl.read_csv('data/post_covid_household_kwh.csv', try_parse_dates=True, schema_overrides={'kWh':pl.Float64})

households_df
# Out:
# shape: (55_604_437, 3)
# ┌─────────────────────────────────┬─────────────────────┬───────┐
# │ id                              ┆ timestamp           ┆ kWh   │
# │ ---                             ┆ ---                 ┆ ---   │
# │ str                             ┆ datetime[μs]        ┆ f64   │
# ╞═════════════════════════════════╪═════════════════════╪═══════╡
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 00:00:00 ┆ 0.021 │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 01:00:00 ┆ 0.02  │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 02:00:00 ┆ 0.021 │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 03:00:00 ┆ 0.02  │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 04:00:00 ┆ 0.02  │
# │ …                               ┆ …                   ┆ …     │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 19:00:00 ┆ 0.069 │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 20:00:00 ┆ 0.042 │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 21:00:00 ┆ 0.038 │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 22:00:00 ┆ 0.038 │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 23:00:00 ┆ 0.191 │
# └─────────────────────────────────┴─────────────────────┴───────┘

# %%
random_house = "a72e830a56205c4ea3d4b5d6b84ab43f16591780c2304bad6f07d2fa862164d7"

random_house_df = pl.read_csv(f"data/imputed_goiener_v7/{random_house}.csv", try_parse_dates=True, schema_overrides={'kWh':pl.Float64})
random_house_df
# Out:
# shape: (58_321, 4)
# ┌─────────────────────┬─────┬─────┬─────┐
# │ index               ┆ fl  ┆ kWh ┆ imp │
# │ ---                 ┆ --- ┆ --- ┆ --- │
# │ datetime[μs]        ┆ i64 ┆ f64 ┆ i64 │
# ╞═════════════════════╪═════╪═════╪═════╡
# │ 2017-05-31 00:00:00 ┆ 1   ┆ 0.0 ┆ 0   │
# │ 2017-05-31 01:00:00 ┆ 1   ┆ 0.0 ┆ 0   │
# │ 2017-05-31 02:00:00 ┆ 1   ┆ 0.0 ┆ 0   │
# │ 2017-05-31 03:00:00 ┆ 1   ┆ 0.0 ┆ 0   │
# │ 2017-05-31 04:00:00 ┆ 1   ┆ 0.0 ┆ 0   │
# │ …                   ┆ …   ┆ …   ┆ …   │
# │ 2024-01-24 20:00:00 ┆ 0   ┆ 0.0 ┆ 0   │
# │ 2024-01-24 21:00:00 ┆ 0   ┆ 0.0 ┆ 0   │
# │ 2024-01-24 22:00:00 ┆ 0   ┆ 0.0 ┆ 0   │
# │ 2024-01-24 23:00:00 ┆ 0   ┆ 0.0 ┆ 0   │
# │ 2024-01-25 00:00:00 ┆ 0   ┆ 0.0 ┆ 0   │
# └─────────────────────┴─────┴─────┴─────┘

# %%
households_pc = households_df.filter(
    (pl.col("timestamp")>=pl.datetime(2021, 6, 1)),
    (pl.col("id").is_in(metadata.select("id").unique().to_series())))

households_pc
# Out:
# /var/folders/p8/k1x_fx4j155c41shjqsrmxl00000gn/T/ipykernel_47113/2855521001.py:1: DeprecationWarning: `is_in` with a collection of the same datatype is ambiguous and deprecated.
# Please use `implode` to return to previous behavior.
#
# See https://github.com/pola-rs/polars/issues/22149 for more information.
#   households_pc = households_df.filter(
# shape: (55_604_437, 3)
# ┌─────────────────────────────────┬─────────────────────┬───────┐
# │ id                              ┆ timestamp           ┆ kWh   │
# │ ---                             ┆ ---                 ┆ ---   │
# │ str                             ┆ datetime[μs]        ┆ f64   │
# ╞═════════════════════════════════╪═════════════════════╪═══════╡
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 00:00:00 ┆ 0.021 │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 01:00:00 ┆ 0.02  │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 02:00:00 ┆ 0.021 │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 03:00:00 ┆ 0.02  │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 04:00:00 ┆ 0.02  │
# │ …                               ┆ …                   ┆ …     │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 19:00:00 ┆ 0.069 │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 20:00:00 ┆ 0.042 │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 21:00:00 ┆ 0.038 │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 22:00:00 ┆ 0.038 │
# │ 7d1ec51c8bfc18caa1f44952d6dcfc… ┆ 2022-06-27 23:00:00 ┆ 0.191 │
# └─────────────────────────────────┴─────────────────────┴───────┘

# %%
households_pc.group_by("id").agg(
    (pl.col("kWh") < 0.001).sum().alias("n_lt_0_01")
)
# Out:
# shape: (3_322, 2)
# ┌─────────────────────────────────┬───────────┐
# │ id                              ┆ n_lt_0_01 │
# │ ---                             ┆ ---       │
# │ str                             ┆ u32       │
# ╞═════════════════════════════════╪═══════════╡
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 1793      │
# │ d55da756a9630ae70ab7bf730cbc17… ┆ 71        │
# │ 9033c69074386e77e702d5f4397e41… ┆ 8         │
# │ 651a7b5098fded45146e3669f2bd57… ┆ 9         │
# │ 5bd9d0e964f9084afa2f5c39293feb… ┆ 2         │
# │ …                               ┆ …         │
# │ 90a0237be98ad718666a8d33ad564e… ┆ 204       │
# │ ac92ac4db88764d2ca4b8eabe92de8… ┆ 0         │
# │ 48d0f7d38c0c092f15bd76cc836fe9… ┆ 25        │
# │ 446a315ea4787562bb137e9b06bb39… ┆ 3715      │
# │ 37dbea233835d38974b631fbaa0b15… ┆ 601       │
# └─────────────────────────────────┴───────────┘

# %%
household_id = "41cd497e6d0d77ab62647284ffe56c643ce5d98b7f43d7b24c3859085baabcf5"

one_house = households_pc.filter(pl.col("id") == household_id)
one_house
# Out:
# shape: (14_399, 3)
# ┌─────────────────────────────────┬─────────────────────┬───────┐
# │ id                              ┆ timestamp           ┆ kWh   │
# │ ---                             ┆ ---                 ┆ ---   │
# │ str                             ┆ datetime[μs]        ┆ f64   │
# ╞═════════════════════════════════╪═════════════════════╪═══════╡
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2021-11-30 01:00:00 ┆ 0.0   │
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2021-11-30 02:00:00 ┆ 0.0   │
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2021-11-30 03:00:00 ┆ 0.0   │
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2021-11-30 04:00:00 ┆ 0.0   │
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2021-11-30 05:00:00 ┆ 0.0   │
# │ …                               ┆ …                   ┆ …     │
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2023-07-22 19:00:00 ┆ 0.05  │
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2023-07-22 20:00:00 ┆ 0.066 │
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2023-07-22 21:00:00 ┆ 0.067 │
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2023-07-22 22:00:00 ┆ 0.049 │
# │ 41cd497e6d0d77ab62647284ffe56c… ┆ 2023-07-22 23:00:00 ┆ 0.115 │
# └─────────────────────────────────┴─────────────────────┴───────┘

# %%
df = households_pc

# 1) daily total per id
daily = (
    df.with_columns(pl.col("timestamp").dt.date().alias("date"))
      .group_by(["id", "date"])
      .agg(pl.col("kWh").sum().alias("kwh_day"))
      .with_columns((pl.col("kwh_day") < 0.01).alias("zero_day"))
      .sort(["id", "date"])
)

# 2) find consecutive-day runs of zero_day=True (length >= 2)
ids_with_2_consecutive_zero_days = (
    daily.filter(pl.col("zero_day"))
         .with_columns(
             # start a new run when date is not previous date + 1 day
             (pl.col("date").diff().over("id") != pl.duration(days=1))
             .fill_null(True)
             .alias("new_run")
         )
         .with_columns(
             pl.col("new_run").cum_sum().over("id").alias("run_id")
         )
         .group_by(["id", "run_id"])
         .agg(pl.len().alias("run_len"))
         .filter(pl.col("run_len") >= 2)
         .select("id")
         .unique()
)

ids_with_2_consecutive_zero_days
# Out:
# shape: (745, 1)
# ┌─────────────────────────────────┐
# │ id                              │
# │ ---                             │
# │ str                             │
# ╞═════════════════════════════════╡
# │ ffd19f52a6fd57060368ae718393de… │
# │ e35482a29c6c363e7130e487557bc3… │
# │ 18477080afbd5441ee18c32858c5bb… │
# │ 2b56008fb8c30d0fefe0f802866372… │
# │ 839e22f97877547fd16fce2bb73be5… │
# │ …                               │
# │ 1fb89cda7e8c12d58b5cf2c9e615bd… │
# │ c83cca0ea4102f4d3106e346ce226d… │
# │ d9dfb51b37562b842cc0768f3ea5b3… │
# │ ff499bbb3527d372931a7313f731ae… │
# │ c89e597234815b4128f4816f27e344… │
# └─────────────────────────────────┘

# %%
clean_df = households_pc.join(
    ids_with_2_consecutive_zero_days, on="id", how="anti"
)

clean_df
# Out:
# shape: (42_526_998, 3)
# ┌─────────────────────────────────┬─────────────────────┬───────┐
# │ id                              ┆ timestamp           ┆ kWh   │
# │ ---                             ┆ ---                 ┆ ---   │
# │ str                             ┆ datetime[μs]        ┆ f64   │
# ╞═════════════════════════════════╪═════════════════════╪═══════╡
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 00:00:00 ┆ 0.021 │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 01:00:00 ┆ 0.02  │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 02:00:00 ┆ 0.021 │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 03:00:00 ┆ 0.02  │
# │ 8a0f77af6f419bb69998d048c27614… ┆ 2021-06-01 04:00:00 ┆ 0.02  │
# │ …                               ┆ …                   ┆ …     │
# │ 67e4ec6efbc8cd1a75a56b02c9a333… ┆ 2024-01-24 20:00:00 ┆ 0.697 │
# │ 67e4ec6efbc8cd1a75a56b02c9a333… ┆ 2024-01-24 21:00:00 ┆ 0.765 │
# │ 67e4ec6efbc8cd1a75a56b02c9a333… ┆ 2024-01-24 22:00:00 ┆ 1.164 │
# │ 67e4ec6efbc8cd1a75a56b02c9a333… ┆ 2024-01-24 23:00:00 ┆ 0.727 │
# │ 67e4ec6efbc8cd1a75a56b02c9a333… ┆ 2024-01-25 00:00:00 ┆ 0.78  │
# └─────────────────────────────────┴─────────────────────┴───────┘

# %%
# metadata = pl.read_csv('data/metadata_post_covid_households_year.csv', try_parse_dates=True, schema_overrides={'cnae':pl.String, 'postal_code':pl.String, 'p1_kw':pl.String}).select("id", "cnae", "postal_code", "start_date", "end_date", "p1_kw", "tarriff")
# metadata

# %%
clean_with_metadata_df = clean_df.join(metadata, on="id", how="left").select(['id',
 'timestamp',
 'kWh',
 'start_date',
 'end_date',
 'cnae',
 'postal_code',
 'p1_kw',
 'tarriff'])
clean_with_metadata_df
# Out:
# shape: (42_821_464, 9)
# ┌─────────────────┬────────────────┬───────┬────────────┬───┬──────┬─────────────┬───────┬─────────┐
# │ id              ┆ timestamp      ┆ kWh   ┆ start_date ┆ … ┆ cnae ┆ postal_code ┆ p1_kw ┆ tarriff │
# │ ---             ┆ ---            ┆ ---   ┆ ---        ┆   ┆ ---  ┆ ---         ┆ ---   ┆ ---     │
# │ str             ┆ datetime[μs]   ┆ f64   ┆ date       ┆   ┆ str  ┆ str         ┆ str   ┆ str     │
# ╞═════════════════╪════════════════╪═══════╪════════════╪═══╪══════╪═════════════╪═══════╪═════════╡
# │ 8a0f77af6f419bb ┆ 2021-06-01     ┆ 0.021 ┆ 2021-06-01 ┆ … ┆ 9810 ┆ 31300       ┆ 2.3   ┆ 2.0TD   │
# │ 69998d048c27614 ┆ 00:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ 8a0f77af6f419bb ┆ 2021-06-01     ┆ 0.02  ┆ 2021-06-01 ┆ … ┆ 9810 ┆ 31300       ┆ 2.3   ┆ 2.0TD   │
# │ 69998d048c27614 ┆ 01:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ 8a0f77af6f419bb ┆ 2021-06-01     ┆ 0.021 ┆ 2021-06-01 ┆ … ┆ 9810 ┆ 31300       ┆ 2.3   ┆ 2.0TD   │
# │ 69998d048c27614 ┆ 02:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ 8a0f77af6f419bb ┆ 2021-06-01     ┆ 0.02  ┆ 2021-06-01 ┆ … ┆ 9810 ┆ 31300       ┆ 2.3   ┆ 2.0TD   │
# │ 69998d048c27614 ┆ 03:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ 8a0f77af6f419bb ┆ 2021-06-01     ┆ 0.02  ┆ 2021-06-01 ┆ … ┆ 9810 ┆ 31300       ┆ 2.3   ┆ 2.0TD   │
# │ 69998d048c27614 ┆ 04:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆ …              ┆ …     ┆ …          ┆ … ┆ …    ┆ …           ┆ …     ┆ …       │
# │ 67e4ec6efbc8cd1 ┆ 2024-01-24     ┆ 0.697 ┆ 2021-06-01 ┆ … ┆ 9820 ┆ 31621       ┆ 4.6   ┆ 2.0TD   │
# │ a75a56b02c9a333 ┆ 20:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ 67e4ec6efbc8cd1 ┆ 2024-01-24     ┆ 0.765 ┆ 2021-06-01 ┆ … ┆ 9820 ┆ 31621       ┆ 4.6   ┆ 2.0TD   │
# │ a75a56b02c9a333 ┆ 21:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ 67e4ec6efbc8cd1 ┆ 2024-01-24     ┆ 1.164 ┆ 2021-06-01 ┆ … ┆ 9820 ┆ 31621       ┆ 4.6   ┆ 2.0TD   │
# │ a75a56b02c9a333 ┆ 22:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ 67e4ec6efbc8cd1 ┆ 2024-01-24     ┆ 0.727 ┆ 2021-06-01 ┆ … ┆ 9820 ┆ 31621       ┆ 4.6   ┆ 2.0TD   │
# │ a75a56b02c9a333 ┆ 23:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ 67e4ec6efbc8cd1 ┆ 2024-01-25     ┆ 0.78  ┆ 2021-06-01 ┆ … ┆ 9820 ┆ 31621       ┆ 4.6   ┆ 2.0TD   │
# │ a75a56b02c9a333 ┆ 00:00:00       ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# │ …               ┆                ┆       ┆            ┆   ┆      ┆             ┆       ┆         │
# └─────────────────┴────────────────┴───────┴────────────┴───┴──────┴─────────────┴───────┴─────────┘

# %%
clean_df.write_csv('data/households_post_covid_year.csv')

# %%
clean_with_metadata_df.write_csv('data/households_post_covid_features.csv')
